# %%
from pandas_ods_reader import read_ods
import pandas as pd
base_path = "agrihack.ods"
sheet_index = 1
df = read_ods(base_path , sheet_index )
df.head()
# Out:
#    temperature  moisture  humidity  nitrogen  phosphorous  potassium  output
# 0         25.0      70.0      70.0     120.0         60.0       60.0     1.0
# 1         30.0      70.0      70.0     120.0         60.0       60.0     1.0
# 2         35.0      70.0      70.0     120.0         60.0       60.0     1.0
# 3         25.0      75.0      70.0     120.0         60.0       60.0     1.0
# 4         30.0      75.0      70.0     120.0         60.0       60.0     1.0

# %%
df.shape
# Out:
# (4038, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4038 entries, 0 to 4037
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   temperature  4038 non-null   float64
#  1   moisture     4038 non-null   float64
#  2   humidity     4038 non-null   float64
#  3   nitrogen     4038 non-null   float64
#  4   phosphorous  4038 non-null   float64
#  5   potassium    4038 non-null   float64
#  6   output       4038 non-null   float64
# dtypes: float64(7)
# memory usage: 221.0 KB

# %%
import seaborn as sb
sb.boxplot(df['temperature'])
# Out:
# <AxesSubplot: >

# %%
sb.boxplot(df['moisture'])
# Out:
# <AxesSubplot: >

# %%
sb.boxplot(df['humidity'])
# Out:
# <AxesSubplot: >

# %%
sb.boxplot(df['nitrogen'])
# Out:
# <AxesSubplot: >

# %%
sb.boxplot(df['phosphorous'])
# Out:
# <AxesSubplot: >

# %%
sb.boxplot(df['potassium'])
# Out:
# <AxesSubplot: >

# %%
import matplotlib.pyplot as plt

# %%
sb.heatmap(df.corr(),cmap="YlGnBu",annot=True)
plt.show()

# %%
df.columns
# Out:
# Index(['temperature', 'moisture', 'humidity', 'nitrogen', 'phosphorous',
#        'potassium', 'output'],
#       dtype='object')

# %%
independent = df[['temperature','moisture','humidity','nitrogen','phosphorous','potassium']]
dependent = df['output']

# %%
independent.head()
# Out:
#    temperature  moisture  humidity  nitrogen  phosphorous  potassium
# 0         25.0      70.0      70.0     120.0         60.0       60.0
# 1         30.0      70.0      70.0     120.0         60.0       60.0
# 2         35.0      70.0      70.0     120.0         60.0       60.0
# 3         25.0      75.0      70.0     120.0         60.0       60.0
# 4         30.0      75.0      70.0     120.0         60.0       60.0

# %%
dependent.head()
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    1.0
# Name: output, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(independent,dependent,test_size=0.2,random_state=2)

from xgboost import XGBRegressor
from sklearn.metrics import r2_score

# Train the XGBoost model
model = XGBRegressor()
model.fit(x_train, y_train)

# Make predictions on the test set
y_pred = model.predict(x_test)

# %%
x_train.head()
# Out:
#       temperature  moisture  humidity  nitrogen  phosphorous  potassium
# 2744         35.0      90.0      75.0     150.0         80.0       80.0
# 2015         35.0     100.0      80.0     150.0         90.0       70.0
# 3506         35.0     100.0      75.0     150.0         70.0       90.0
# 3245         35.0      85.0      75.0     150.0         60.0       90.0
# 411          25.0      90.0      75.0     140.0         70.0       60.0

# %%
y_train.head()
# Out:
# 2744    1.0
# 2015    1.0
# 3506    1.0
# 3245    1.0
# 411     1.0
# Name: output, dtype: float64

# %%
df.columns
# Out:
# Index(['temperature', 'moisture', 'humidity', 'nitrogen', 'phosphorous',
#        'potassium', 'output'],
#       dtype='object')

# %%
user_input = pd.DataFrame({
    'temperature':40,
    'moisture':2,
    'humidity':0,
    'nitrogen':3,
    'phosphorous':2,
    'potassium':3,
},index=[0])
model.predict(user_input)
# Out:
# array([0.00044541], dtype=float32)

# %%
#user_input = [[40,2,0,3,2,3]]
#model.predict(user_input)

# %%
df = pd.DataFrame({'Actual':y_test,'Prediction':y_pred})
df.head()
# Out:
#       Actual  Prediction
# 2341     1.0    0.999999
# 2220     1.0    0.999999
# 3773     1.0    0.999999
# 1559     1.0    0.999999
# 2261     1.0    0.999999

# %%
# Calculate the R^2 score
r2 = r2_score(y_test, y_pred)
print("R^2 Score: ", r2)
# Out:
# R^2 Score:  0.9999998009723016

# %%
from joblib import dump
dump(model, 'bph_prediction.json')
# Out:
# ['bph_prediction.json']
